# %%
import pandas as pd
from pathlib import Path

file_path = Path().resolve() # Path(__file__).resolve()
project_dir = file_path.parent
raw_data_path = project_dir / 'data' / 'raw'

# %%
pd.read_csv(filepath_or_buffer=raw_data_path / 'Основной.csv', sep=';', engine='python').tail(3)
# Out:
#      Код теста                                      Исследование   \
# 139  AN1271LEV                                      Леветирацетам
# 140   AN900LEV  Лекарственный мониторинг вещества не входящего...
# 141   AN274CYC                                        Циклоспорин
#
#                                         Название в ЛИС Состояние натощак  \
# 139                                      Леветирацетам              12 ч
# 140  Лекарственный мониторинг вещества не входящего...              12 ч
# 141                                        Циклоспорин              12 ч
#
#     Исследуемый биоматериал Номер контейнера  \
# 139         сыворотка крови              807
# 140         сыворотка крови              807
# 141            кровь с ЭДТА              806
#
#                     Важные ПРЕАНАЛИТИЧЕСКИЕ замечания   \
# 139         Минимальный объем сыворотки – 0#comma#5 мл
# 140  необходимо предварительное согласование и обра...
# 141                                                NaN
#
#                      Тип ПЕРВИЧНОГО контейнера  \
# 139                 Пробирка с красной крышкой
# 140                 Пробирка с красной крышкой
# 141  Пробирка с сиреневой крышкой / Калий ЭДТА
#
#     Тип контейнера для ХРАНЕНИЯ и ТРАНСПОРТИРОВКИ  \
# 139                      Пробирка с белой крышкой
# 140                      Пробирка с белой крышкой
# 141     Пробирка с сиреневой крышкой / Калий ЭДТА
#
#     Температура хранения и транспортировки  \
# 139                              +2°С…+8°С
# 140                              +2°С…+8°С
# 141                              +2°С…+8°С
#
#          Правила взятия и пробоподготовки биоматериала
# 139  1. Взятие крови – пробирка с красной крышкой. ...
# 140  1. Взятие крови – пробирка с красной крышкой. ...
# 141  1. Взятие крови – пробирка с сиреневой  крышко...
